# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 
from src.data.prepare_data import crop_images

# %%
image_paths =["data/chess_reader_dataset/131.png", 
              "data/online_dataset/158_0_1_white.png" ]

# gray scale 
images = [
    cv2.imread(p, cv2.IMREAD_GRAYSCALE) 
    for p in image_paths 
]
print(f"image shape: {images[1].shape}")
images[1] = images[1][:,200:]
for image in images:
    print(f"image shape: {image.shape}")
    plt.imshow(image)
    plt.show()
# Out:
# image shape: (147, 965)
# image shape: (177, 300)
# image shape: (147, 765)

# %%
from src.data.prepare_data import rescale_img 

for image in images:
    image = rescale_img(image,45, 200) 
    print(f"image shape: {image.shape}")
    plt.imshow(image)
    plt.show()
# Out:
# image shape: (45, 200)
# image shape: (45, 200)
